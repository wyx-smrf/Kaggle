# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(({   'Ahome' :   pd.Categorical(["home"]*10),
                         'Bsearch' : pd.Categorical(["search"]*8 + ["NO"]*2),
                          'Cbuy' : pd.Categorical(["buy"]*5 + ["NO"]*5),
                          'Dcheck' : pd.Categorical(["check"]*3 + ["NO"]*7),


                     } ))

# %%
df
# Out:
#   Ahome Bsearch Cbuy Dcheck
# 0  home  search  buy  check
# 1  home  search  buy  check
# 2  home  search  buy  check
# 3  home  search  buy     NO
# 4  home  search  buy     NO
# 5  home  search   NO     NO
# 6  home  search   NO     NO
# 7  home  search   NO     NO
# 8  home      NO   NO     NO
# 9  home      NO   NO     NO

# %%
null_values_list = ['Ahome', 'Bsearch', 'Cbuy', 'Dcheck']

plot_params = {'data':               df,
               'columns_list':       null_values_list,
               'condition':          NaN}

def plot_multiple_column():
    df1 = df.melt(value_vars=df.columns)
    df2 = df1[df1["value"] != "NO"]
    sns.countplot(data=df2, x="variable")
    return plt.show()

# %%
df1 = df.melt(value_vars=df.columns)
df2 = df1[df1["value"] != "NO"]
sns.countplot(data=df2, x="variable")
plt.show()

# %%
df1
# Out:
#    variable   value
# 0     Ahome    home
# 1     Ahome    home
# 2     Ahome    home
# 3     Ahome    home
# 4     Ahome    home
# 5     Ahome    home
# 6     Ahome    home
# 7     Ahome    home
# 8     Ahome    home
# 9     Ahome    home
# 10  Bsearch  search
# 11  Bsearch  search
# 12  Bsearch  search
# 13  Bsearch  search
# 14  Bsearch  search
# 15  Bsearch  search
# 16  Bsearch  search
# 17  Bsearch  search
# 18  Bsearch      NO
# 19  Bsearch      NO
# 20     Cbuy     buy
# 21     Cbuy     buy
# 22     Cbuy     buy
# 23     Cbuy     buy
# 24     Cbuy     buy
# 25     Cbuy      NO
# 26     Cbuy      NO
# 27     Cbuy      NO
# 28     Cbuy      NO
# 29     Cbuy      NO
# 30   Dcheck   check
# 31   Dcheck   check
# 32   Dcheck   check
# 33   Dcheck      NO
# 34   Dcheck      NO
# 35   Dcheck      NO
# 36   Dcheck      NO
# 37   Dcheck      NO
# 38   Dcheck      NO
# 39   Dcheck      NO

# %%
scat_params = {'data':              titanic,
               'rows':              'Age',
               'columns':           'Pclass',
               'y_axis':            'Fare',
               'plot_sep':          'Survived'}

def comparative_scatter(data, rows, columns, y_axis, plot_sep):
    scatter_plot = sns.FacetGrid(data, margin_titles=True,
                                 hue=plot_sep, col=columns,
                                 palette={1:"seagreen", 0:"gray"})
    
    scatter_plot.map(plt.scatter, y_axis, rows, edgecolor="w").add_legend()
    
comparative_scatter(**scat_params)
